# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.decomposition import RandomizedPCA,PCA, FastICA, NMF

trainDF = pd.read_csv('train-3.csv')
testDF = pd.read_csv('test-3.csv')

Xtrain = []
colArray = []
for picture in trainDF["Pixels"]:
    col = np.array(map(int, picture.split(' ')))
    colArray.append(col)
Xtrain = np.array(colArray[:-200])
Xval = np.array(colArray[-200:])
n_components = 200

# %%
# %matplotlib inline
X = np.reshape(Xtrain[23], (48,48))
plt.imshow(X)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline


def emotionToPicture(emo):
    trainDF = pd.read_csv('train-3.csv')
    Xbus = []
    collardArray = []
    dicpics = []
    #^this line just enables inline picture display?
    for i in range(len(trainDF["Emotion"])):
        if trainDF["Emotion"][i] == emo:            
            tDF = trainDF["Pixels"][i]
            col = np.array(map(int, tDF.split(' ')))
            col = np.reshape(col, (48,48))
            plt.imshow(col)
            return
        
emotionToPicture(0)
